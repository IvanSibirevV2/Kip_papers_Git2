# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # На тему РАЗРАБОТКА ИНФОРМАЦИОННОЙ СИСТЕМЫ УЧЕТА БРЕНДОВЫХ ВЕЩЕЙ ДЛЯ ИП "ЩЕТИНИН ВЛАДИСЛАВ ВАЛЕРЬЕВИЧ"
# ### Представлено Вишняковым Денисом

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Как зовут руководителя?
#     - Александр Валерьевич Джебиловъ
# - ?
#     - питон киндер sqlite.

# %% [markdown]
# ### Дипломный проект на тему: «АВТОМАТИЗАЦИЯ УЧЁТА ЗАКАЗОВ НА ПРИМЕРЕ ООО DE LUSE»
# ### Обучающийся: Горбунов Павел Анатольевич
# ### Руководитоль: Ребус Наталья Анатольевна

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - В чем разница между «Битрикс» и 1С?
#     - затрудняюсь ответить
# - сильно
# - ...

# %% [markdown]
# ### Дипломный проект на тему «Автоматизация процесса продажи на примере организации ООО «ВИВОНА»»
# ### Обучающийся: Ерамишанцев Даниил Артемович
# ### Руководитель: Гринева Елизавета Сергеевна

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Какой тип связей использовал?
#     - Использовал тип связей таблиц базы данных: один к одному, многие ко многим и один ко многим...
# - (Поясню, там три типа связей, на определенном этапе проектировнаия баз данных остается только один ко многим...)
