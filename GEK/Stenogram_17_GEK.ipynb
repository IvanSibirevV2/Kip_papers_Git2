# %% [markdown]
# # Stenogramm_17_GEK

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Дипломный проект натему "Автомигризщия процесса продежи напримерс торговой органОО "Кочуг""
# ### Обучающийся: Еприкян Тигран Андраникович
# ### Руководитель: Мастяев Филипп Алексеевич

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Поехал шрифт в презентации
#     - В презентации встал криво потому что PDF
# - В чем генерировался диаграмма вызова программных модулей?
#     - Ее рисовал ии....
# - Какой тип связей у ER модели
#     - Затрудняюсь ответить
# - Вопрос про антиплагиат
#     - 91 процент оригинальности кажется...
# - Может что нибудь вспомните примечательное про питон
#     - он прост в освоении

# %% [markdown]
# # Дипломный проект на тему «автоматизация процесса управления транспортной логистики на примере "ИП Дудина Марина Ивановна" »
# ### Обучающийся: Киселёв Богдан Александрович
# ### Руководитель: Солдатова Ольга Борисовна

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - WPF
#     - да
# - MsSQL
#     - ДА - Запросом подключение к MsSQL, через запроса... Потом через ADO.NET Entity Framework
# - Фильтрация при визуализации таблиц данных?
#     - Ответ в стиле "Да/Нет/Сомневаюсь"
# - LinQToObjects?
#     - Нет
# - LinQToSQL?
#     - Нет
#
# (Общий уровень ответа весьма не прохой. Последние вопросы были олимпиадного уровня...)

# %% [markdown]
# # Дипломный Проект на тему «Автоматизация взаимоотношений с клиентами на примере ИП Корзинкин В.В.»
# ### Обучающийся: Корзинкин Владислав Вадимович
# ### Руководитель: Жданцев Кирилл Николаевич

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Использовали ли Вы плагины для VSCode?
#     - Затрудняюсь ответить...
# - Вопрос, судя по всему, был связан с базой данных...  Пользователь и permision никак не связан с остальной базой данных. Прокомментируйте....
#     - никак не связаны. Использовались для разграничения доступа к базе данных...
# - Какая СУБД использовалась?
#     - PostgreSQL
# - Как осуществлялся Git Clone?
#     - мышкой через менеджер!
# - Проверка на уровень доступа?
#     - Осуществляется в бек енде
# - Как осуществляется передача логина пароля? Используется ли шифрование и какое?
#     - в зашифровоном виде библиотекой js

# %% [markdown]
# # Дипломный проект на тему «Автоматизация учета обращений пользователей барбершопа "Зона стиля" »
# ### Обучающийся: Кушназаров Бекназар Умаралиевич
# ### Руководитель: Жданцев Кирилл Николаевич

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Ответы:
#     - PostgreSQL, pgAdmin, адаптивный дизайн, библиотека на сайте, версии для слабовидящих нет, черно-желтый дизайн, однако.

# %% [markdown]
# # Синергия длякАрьем Профиль Информационные системы и программирование
# ### Дипломный проект на тему «Автоматизация процесса продажи на примере Apple Dubai»
# ### Обучающийся: Сиротинский Дмитрий Сергеевич

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Расскажите про стек технологий
#     - html, css, js, база данных php, потом вспомнил про HTML
# - PHP чаще Get или Post запрос
#     - ответ не знаю

# %% [markdown]
# # Дипломный проект на тему «Автоматизация процесса продаж на примере торговой организации "ВananzalMotors »
# ### Обучающийся: Назаров Илья Владимирович
# ### Руководитель: Устинов Евгений Вячеславович

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Аргументируйте пожалуйсто связь вида 1 к 1
#     - клиент имеет один аккаунт пользователя на сайте
#     - На один заказ один платеж
#     - компания не выдает рассрочку
#     - "деньги на стол "=)
# - Какие технологии истользуются?
#     - PostgreSQL
# - Язык сервера?
#     - ?
# - Язык фронтенда?
#     - js
#     - c# - фронтенд
#     - В последнем высказывании мы фатально упорствовали.

# %% [markdown]
# # Дипломный Проект На тему Отладка и разработка тестовых наборов и сценариев при автоматизации продаж "Wildberries"
# ### Обучающийся: Унежев Михаил Романович
# ### Руководитель: Сибирев Иван Валерьевич

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопросов не задавал

# %% [markdown]
# # Дипломный проект на тему «Автоматизация анализа продаж на примере компании ПАО "X5RetailGroup"
# ### Обучающийся: Шулыгин Антон Андреевич
# ### Руководитель: Горшкова Анастас

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Есть логическая ER модель, есть физическая ER модель, чем они отличаются?
#     - Отличаются степенью подробности?
# - 3 таблицы в базе данных?
#     - связанны они быть не обязаны.
# - Почему именно 3 таблицы?
#     - В примере оно было так
#     - "Так решил руководитель" ...
# - Кто защищается?
#     - Руководитель ... То есть я ...

# %% [markdown]
# # Дипломный проект «Автоматизация процесса продаж на примере торговой марки Dark
# ### Обучающийся: Шушпанов Сергей Сергеевич
# ### Руководитель: Гринева Елизавета Сергеевна

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Стек технологий...
#     - C#
#     - WinForm
#     - PHP
#     - MySQL
#     - Ставил данвер
#     - сказал что это проще
# - Разница между битрикс и 1c?
#     - затрудняюсь ответить
# - Какая была VS 2020?
#     - После установки позволяет ВЫДИРАТЬ UML диаграммы классов
# - Позволяет ли называть классы русскими символами?
#     - молчание если не ошибаюсь

# %% [markdown]
# # Дипломный проект на тему "Автоматизация анализа продаж товаров и услуг ООО "Вайлдберриз""
# ### Обучающийся: Декастро Глеб Витольдович
# ### Руководитель: Скопин Владимир Игоревич

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Технологии...
#     - Linux Python 1C
# - Как это коррелируется?
#     - кивает (на самом деле вещи несовместимые, во всяком случае на студенческом уровне, да и много лет после...)
# - На вопрос откуда питон берет данные был дан ответ...
#     - они сгенерированны
# - На вопрос Linux?
#     - ответ писал сам исходя из своих наработок
#     - (Видемо у учащегося нехилые такие наработки...)
# - На вопрос как ставился 1C на линукс был дан ответ...
#     - что 1С отдельно Linux отдельно
#     - У ваилдбериса есть данные они их не дают ()
#     - пустота
#     - питон есть сгенерированные данные.........
#     - генерировал сам?!
#     - Поля данных питона были под впечатлением данных вайлдбериса.....
#     - Я зарегистрировался как рабочий Вайлбериса как продавец...
#     - Попросили 30 тысяч рублей .... дальнейшего доступа к данным не было
#     (В целом это было фиаско.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - в ER диаграмме есть таблица без связей...
#     - ответ, есть соседняя ER диаграмма со связями
#     (в целом ответ был хороший)
