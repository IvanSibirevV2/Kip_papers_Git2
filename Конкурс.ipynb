# %% [markdown]
# # Подача документов на конкурс

# %% [markdown]
# https://contest.synergy.ru/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://publications.lms.synergy.ru/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png).

# %% [markdown]
# https://elibrary.ru/project_author_tools.asp

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://elibrary.ru/author_profile.asp?id=856704

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://elibrary.ru/author_items.asp?orgsid=5315

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Поздравляем Зайцева А.И., Скопина В.И., Сибирева И.В., Чантурия Г.Т. с выходом статья в журнале К1 (ЯДРО)!
# http://pribor.tgizd.ru/ru/arhiv/23573
#
#
#
#
#
#
# Поздравляем Зайцева А.И., Сибирева И.В., Скопина В.И., Чантурия Г.Т. со статьей в журнале К1 (ЯДРО)!
# https://www.elibrary.ru/item.asp?id=82304122

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Там нужны +
# Email всех авторов.
# Статья из Елайбрари не подтягивается
#
# Есть ли pdf
